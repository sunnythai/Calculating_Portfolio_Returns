# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers= ["TSLA", "CRSP", "ROKU", "TDOC", "SQ",
          "NVTA", "TWST","PACB", "PSTG", "Z",
          "EDIT", "IOVA", "SPOT", "NTLA","EXAS",
          "PRLB","TWLO", "MTLS","PYPL","BIDU", 
          "SHOP", "DOCU","ICE", "TSM", "TREE"]

print (len(tickers))
mydata=pd.DataFrame()
for t in tickers:
    mydata[t]=wb.DataReader (t, data_source='yahoo', start='2020-1-1', end='2020-12-24')['Adj Close']
# Out:
# 25

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 249 entries, 2020-01-02 to 2020-12-24
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TSLA    249 non-null    float64
#  1   CRSP    249 non-null    float64
#  2   ROKU    249 non-null    float64
#  3   TDOC    249 non-null    float64
#  4   SQ      249 non-null    float64
#  5   NVTA    249 non-null    float64
#  6   TWST    249 non-null    float64
#  7   PACB    249 non-null    float64
#  8   PSTG    249 non-null    float64
#  9   Z       249 non-null    float64
#  10  EDIT    249 non-null    float64
#  11  IOVA    249 non-null    float64
#  12  SPOT    249 non-null    float64
#  13  NTLA    249 non-null    float64
#  14  EXAS    249 non-null    float64
#  15  PRLB    249 non-null    float64
#  16  TWLO    249 non-null    float64
#  17  MTLS    249 non-null    float64
#  18  PYPL    249 non-null    float64
#  19  BIDU    249 non-null    float64
# ...

# %%
mydata.head()
# Out:
#                  TSLA       CRSP        ROKU       TDOC         SQ       NVTA  \
# Date
# 2020-01-02  86.052002  59.320000  137.100006  83.260002  63.830002  16.350000
# 2020-01-03  88.601997  59.439999  137.509995  82.959999  63.000000  16.120001
# 2020-01-06  90.307999  59.950001  143.369995  86.940002  62.570000  16.049999
# 2020-01-07  93.811996  60.349998  138.190002  85.730003  64.589996  15.780000
# 2020-01-08  98.428001  62.529999  134.639999  86.220001  67.599998  16.260000
#
#                  TWST  PACB       PSTG          Z  ...        PRLB  \
# Date                                               ...
# 2020-01-02  20.850000  5.16  17.799999  45.209999  ...  101.230003
# 2020-01-03  20.889999  5.26  17.420000  44.720001  ...   99.430000
# 2020-01-06  22.340000  5.19  17.629999  44.639999  ...  100.110001
# 2020-01-07  21.459999  4.92  17.709999  45.770000  ...  100.050003
# 2020-01-08  21.230000  4.71  18.040001  45.770000  ...  101.400002
#
# ...

# %%
mydata.tail()
# Out:
#                   TSLA        CRSP        ROKU        TDOC          SQ  \
# Date
# 2020-12-18  695.000000  148.610001  340.709991  196.339996  235.449997
# 2020-12-21  649.859985  166.839996  354.000000  199.750000  233.500000
# 2020-12-22  640.340027  170.080002  354.709991  206.039993  241.580002
# 2020-12-23  645.979980  173.229996  360.559998  209.419998  230.679993
# 2020-12-24  661.770020  168.500000  356.989990  207.949997  228.279999
#
#                  NVTA        TWST       PACB       PSTG           Z  ...  \
# Date                                                                 ...
# 2020-12-18  47.560001  147.339996  20.100000  22.469999  135.199997  ...
# 2020-12-21  50.000000  152.000000  23.040001  22.790001  136.399994  ...
# 2020-12-22  53.080002  167.889999  26.950001  23.459999  140.660004  ...
# 2020-12-23  50.990002  166.759995  28.500000  24.200001  141.229996  ...
# 2020-12-24  47.070000  164.039993  27.129999  23.980000  138.639999  ...
#
# ...

# %%
mydata.iloc[0]
# Out:
# TSLA     86.052002
# CRSP     59.320000
# ROKU    137.100006
# TDOC     83.260002
# SQ       63.830002
# NVTA     16.350000
# TWST     20.850000
# PACB      5.160000
# PSTG     17.799999
# Z        45.209999
# EDIT     29.440001
# IOVA     26.680000
# SPOT    151.619995
# NTLA     14.580000
# EXAS     95.580002
# PRLB    101.230003
# TWLO    103.150002
# MTLS     18.610001
# PYPL    110.750000
# BIDU    138.220001
# SHOP    407.809998
# DOCU     75.900002
# ICE      91.508072
# TSM      58.484398
# TREE    306.959991
# Name: 2020-01-02 00:00:00, dtype: float64

# %%
(mydata/mydata.iloc[0]*100).plot(figsize=(20,10)); #normalizing/normalization the stock prices by multiplying by 100
plt.savefig('/Users/sunnythai/Desktop/graf.png')
plt.show()

# %%
mydata.loc['2020-12-24']
# Out:
# TSLA     661.770020
# CRSP     168.500000
# ROKU     356.989990
# TDOC     207.949997
# SQ       228.279999
# NVTA      47.070000
# TWST     164.039993
# PACB      27.129999
# PSTG      23.980000
# Z        138.639999
# EDIT      83.529999
# IOVA      49.549999
# SPOT     328.390015
# NTLA      62.139999
# EXAS     139.559998
# PRLB     172.550003
# TWLO     362.880005
# MTLS      56.410000
# PYPL     238.639999
# BIDU     191.020004
# SHOP    1225.520020
# DOCU     244.929993
# ICE      112.690002
# TSM      105.970001
# TREE     277.450012
# Name: 2020-12-24 00:00:00, dtype: float64

# %%
returns =(mydata/mydata.shift(1))-1
returns.head()
# Out:
#                 TSLA      CRSP      ROKU      TDOC        SQ      NVTA  \
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-01-03  0.029633  0.002023  0.002990 -0.003603 -0.013003 -0.014067
# 2020-01-06  0.019255  0.008580  0.042615  0.047975 -0.006825 -0.004343
# 2020-01-07  0.038801  0.006672 -0.036130 -0.013918  0.032284 -0.016822
# 2020-01-08  0.049205  0.036123 -0.025689  0.005716  0.046602  0.030418
#
#                 TWST      PACB      PSTG         Z  ...      PRLB      TWLO  \
# Date                                                ...
# 2020-01-02       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2020-01-03  0.001918  0.019380 -0.021348 -0.010838  ... -0.017781  0.003587
# 2020-01-06  0.069411 -0.013308  0.012055 -0.001789  ...  0.006839  0.038060
# 2020-01-07 -0.039391 -0.052023  0.004538  0.025314  ... -0.000599  0.005583
# 2020-01-08 -0.010718 -0.042683  0.018634  0.000000  ...  0.013493  0.012308
#
# ...

# %%
weights=np.array([0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04,])

# %%
np.dot(returns, weights)
# Out:
# array([            nan, -6.96742640e-03,  1.36670869e-02,  1.28161087e-04,
#         1.49915866e-02,  5.76714185e-03, -3.32820095e-03,  8.23642010e-03,
#         4.20794549e-03,  4.68417962e-03,  5.61114575e-03, -8.07813598e-03,
#        -6.99657567e-04,  7.81233332e-03, -4.62663554e-03, -9.67303772e-03,
#        -1.63369771e-02,  1.98579884e-02,  4.69463573e-03,  1.16883430e-03,
#        -1.92888064e-02,  2.90016932e-02,  3.32953391e-02, -6.39575222e-03,
#         6.85488393e-03, -1.02186665e-02,  2.26063390e-02,  2.23229114e-03,
#         1.56252096e-02,  3.63649924e-03, -3.31577948e-03,  3.50788500e-03,
#         1.17037012e-02,  4.03591261e-03, -2.18715894e-02, -3.29136527e-02,
#        -2.60569144e-02, -1.15027655e-02, -2.07651933e-02,  1.37379180e-02,
#         2.10633324e-02, -2.22327942e-02,  3.63552042e-02, -1.42730026e-02,
#        -2.20786401e-02, -8.46056013e-02,  3.66364939e-02, -6.21053328e-02,
# ...

# %%
annual_returns=returns.mean()*250
annual_returns
# Out:
# TSLA    2.467773
# CRSP    1.269204
# ROKU    1.234890
# TDOC    1.177760
# SQ      1.561454
# NVTA    1.588884
# TWST    2.411008
# PACB    2.020453
# PSTG    0.514136
# Z       1.408765
# EDIT    1.439227
# IOVA    0.965137
# SPOT    0.930671
# NTLA    1.851001
# EXAS    0.678946
# PRLB    0.705686
# TWLO    1.496171
# MTLS    1.461706
# PYPL    0.911799
# BIDU    0.419636
# SHOP    1.336795
# DOCU    1.362893
# ICE     0.283930
# TSM     0.703732
# TREE    0.123524
# dtype: float64

# %%
np.dot(annual_returns,weights)
# Out:
# 1.2130072214222651

# %%
pfolio_1=str(round(np.dot(annual_returns, weights),4)*100)+ '%'
print (pfolio_1)
# Out:
# 121.30000000000001%
